# %% [markdown]
# # Personalización básica, Countplot, Boxplot y Violinplot  - Day 4
# ### Countplot

# %% [markdown]
# El countplot es un gráfico de barras que muestra el conteo de observaciones en cada categoria de una variable categorica.<br>
# Distribución de categorias: Ideal para ver cómo se distribuyen las observaciones entre diferentes categorias.<br>
# Análisis de encuestas: Útil para visualizar respuestas a preguntas de opción múltiple.<br>

# %%
# Import libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load dataset
titanic = sns.load_dataset("titanic")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
# Set style and palette

sns.set_style('darkgrid')

# Set palette
sns.set_palette('pastel')

# %% [markdown]
# ### Basic countplot

# %%
plt.figure(figsize=(8,6)) # tamaño de la figura

sns.countplot(
        data=titanic,
        x='class',
        hue='class'
)

plt.xticks(rotation=25)

plt.title("CountPlot of class")

plt.show()

# %%
# Define order of the classes:

plt.figure(figsize=(8,6))

sns.countplot(
        data=titanic,
        x='class',
        hue='class',
        order=["Third", "Second", "First"]
)


plt.xticks(rotation=20)

plt.title("Countplot with specific order")

plt.show()

# %%
# Seaborn ofrece varias paletas de colores predefinidas: palette=

plt.figure(figsize=(8,6))

sns.countplot(
        data=titanic,
        x='class',
        hue='class',
        order=['Third', 'Second', 'First'],
        palette='dark:skyblue'
)

plt.xticks(rotation=25)

plt.title("Countplot with specific order and colors")
plt.xlabel("Class")
plt.ylabel("Count")

plt.show()

# %%
# El gráfico puede ser en sentido vertical (default) en x. O en sentido horizontal en y.

plt.figure(figsize=(8,6))

sns.countplot(
        data=titanic,
        y='class', # Define y for the categories
        hue='class',
        palette='dark:red',
        order=['Third', 'Second', 'First'],
        alpha=0.7
)

plt.yticks(rotation=25)

plt.xlabel("Count")
plt.ylabel("Class")
plt.title("Countplot in horizontal")

plt.show()

# %%
# Añadir una segunda variabel categórica con 'hue'

plt.figure(figsize=(8,6))

sns.countplot(
        data=titanic,
        x='class', # Variable principal
        hue='sex', # Segunda variable
        order=['Third', 'Second', 'First'],
        palette='dark:green',
        alpha=0.6
)

plt.xticks(rotation=25)

plt.title("Countplot by class and a second variable")
plt.xlabel("Class")
plt.ylabel("Count")

plt.show()

# %%
# Ajustar el tamaño de las barras

plt.figure(figsize=(10,8))

sns.countplot(
        data=titanic,
        x='class',
        hue='sex',
        palette='dark:yellow',
        alpha=0.5,
        order=["Third", "Second", "First"],
        width=0.25
)

plt.xticks(rotation=25)

plt.title("Countplot with specific bar width")
plt.xlabel("Class")
plt.ylabel("Count")

plt.show()

# %%
# Añadir etiquetas de datos

plt.figure(figsize=(8,6))

# Save the graph in a variable - ax

ax = sns.countplot(
        data=titanic,
        x='class',
        hue='sex',
        palette='dark:skyblue',
        alpha=0.4,
        order=["Third", "Second", "First"],
        width=0.3,
        linewidth=0.7, # tamaño del borde de las barras
        edgecolor='black' # Color del borde de las barras
)

for container in ax.containers:
    ax.bar_label(container)

plt.xticks(rotation=25)

plt.title("Countplot with labels on bars")
plt.xlabel("Class")
plt.ylabel("Count")

plt.show()

# %%
# Ajustar eje y

plt.figure(figsize=(8,6))

ax = sns.countplot(
        data=titanic,
        x='class',
        hue='sex',
        palette='dark:skyblue',
        order=["Third", "Second", "First"],
        alpha=0.6,
        width=0.5,
        linewidth=0.5,
        edgecolor='black'
)

for container in ax.containers:
    ax.bar_label(container)


plt.xticks(rotation=25)

plt.ylim(0,400)

plt.title("Countplot with ylimit specific")
plt.xlabel("Class")
plt.ylabel("Count")


plt.show()

# %%
# Controlar leyenda

plt.figure(figsize=(8,6))

ax = sns.countplot(
        data=titanic,
        x="class",
        hue="sex",
        order=["Third", "Second", "First"],
        palette="dark:skyblue",
        alpha=0.6,
        width=0.6,
        linewidth=0.5,
        edgecolor="black"

)

for container in ax.containers:
    ax.bar_label(container)

plt.ylim(0,400)
plt.xticks(rotation=25)
plt.legend(title="Sex", loc=5)

plt.title("Countplot with legend control")
plt.xlabel("Class")
plt.ylabel("Count")

plt.show()
