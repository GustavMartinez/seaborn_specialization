# %% [markdown]
# # Personalización básica, Boxplot - Day 5
# ### Boxplot

# %% [markdown]
# El boxplot, también conocido como diagrama de caja y bigotes, es una herramienta útil para visualizar la distribución de datos numéricos.<br>
# Un boxplot muestra la distribución de datos numéricos a través de sus cuartiles. Proporciona también una visión de la mediana, la dispersión y la simetria de los datos, asi como de valores atípicos.

# %% [markdown]
# Componentes:<br>
# Caja Central: Representa el rango intercuartílico (IQR), que va del primer cuartil (Q1) al tercer cuartil (Q3).<br>
# Línea dentro de la caja: Representa la mediana (segundo cuartil, Q2)<br>
# Bigotes: Líneas que se extienden desde la caja hasta los valores mínimo y máximo dentro de 1.5 veces el IQR.<br>
# Puntos individuales: Representan valores atípicos que caen fuera del rango de los bigotes.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
tips = sns.load_dataset("tips")

# %%
tips.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
# Set style and palette:

sns.set_style('darkgrid')
sns.set_palette('pastel')

# %%
# Basic boxplot:

plt.figure(figsize=(8,6))

sns.boxplot(
    data=tips,
    y="total_bill"
)

plt.title("Basic boxplot")

plt.show()

# %%
# Orientacion del boxplot: y vertical; x horizontal

plt.figure(figsize=(8,6))

sns.boxplot(
        data=tips,
        x='total_bill'
)

plt.title("Horizontal Boxplot")

plt.show()

# %%
# Adicionar una variable categorica
# El parámetro 'hue' permite dividir los datos por una segunda variable categórica, como el sexo.

plt.figure(figsize=(8,6))

sns.boxplot(
        data=tips,
        y='total_bill',
        hue='sex'
)


plt.legend(title='Sex')

plt.title("Boxplot with a categorical variable")
plt.ylabel("Total Bill")

plt.show()

# %%
# Defining a specific palette:

plt.figure(figsize=(8,6))

sns.boxplot(
        data=tips,
        y='total_bill',
        hue='sex',
        palette='viridis'
)

plt.legend(title='Sex')

plt.title('Boxplot with specific palette')
plt.ylabel('Total Bill')


plt.show()

# %%
# Control of the order of the categories

plt.figure(figsize=(8,6))

sns.boxplot(
        data=tips,
        y='total_bill',
        x='sex',
        hue='sex',
        palette='light:skyblue',
        order=['Female', 'Male']
)


plt.title('Boxplot with specific order')
plt.ylabel('Total Bill')

plt.show()

# %%
# Grosor de las lineas con el parametro linewidth

plt.figure(figsize=(8,6))

sns.boxplot(
        data=tips,
        y='total_bill',
        x='sex',
        hue='sex',
        palette='light:skyblue',
        order=['Female', 'Male'],
        linewidth=1
)

plt.title("Boxplot with line thiknes")
plt.ylabel('Total bill')
plt.xlabel('Sex')

plt.show()

# %%
# Mostrar valores atipicos - Outliers

plt.figure(figsize=(8,6))

sns.boxplot(
        data=tips,
        y='total_bill',
        x='sex',
        hue='sex',
        palette='light:skyblue',
        order=['Female', 'Male'],
        linewidth=1,
        showfliers=False
)

plt.title("Boxplot without outliers")
plt.ylabel("Total bill")
plt.xlabel("Sex")

plt.show()
